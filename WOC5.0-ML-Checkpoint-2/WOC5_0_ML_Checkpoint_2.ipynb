# %% [markdown]
# <a href="https://colab.research.google.com/github/Devdeep-J-S/woc5.0-ml-weather-prediction-case-study-Devdeep/blob/main/WOC5.0-ML-Checkpoint-2/WOC5_0_ML_Checkpoint_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1) Reading the above CSV file in google colab using the pandas’ library and converting it into data frames.

# %%
# data from drive 
import pandas as pd
path = 'https://raw.githubusercontent.com/Devdeep-J-S/woc5.0-ml-weather-prediction-case-study-Devdeep/main/WOC5.0-ML-Checkpoint-2/Youtube%20Influencer%20Analysis%20-%20Updated.csv'
df = pd.read_csv(path,sep=",", encoding='mac_roman')

# %%
# first 5 row print 
df.head()
# Out:
#                                           Video Link Video Views  \
# 0        https://www.youtube.com/watch?v=_0fUOJ55gis     146,059
# 1        https://www.youtube.com/watch?v=_70MSLPRfZI     231,969
# 2  https://www.youtube.com/watch?v=_8gfCdt3H00&t=87s         878
# 3        https://www.youtube.com/watch?v=_CkFNJgKsFs       9,965
# 4        https://www.youtube.com/watch?v=_GFkHA5EZdE  39,780,561
#
#                                          Video Title  \
# 0    Samse - Didupe Off-road Royal Enfield Himalayan
# 1                           Bhoom Baddhal Web Series
# 2  Customer Psychology, Four Views Of Consumer De...
# 3     Top countries with proven natural gas reserves
# 4                     73 Questions With Selena Gomez
#
#                                          Channel URL Creator Name  \
# 0                https://www.youtube.com/c/sriharick   srihari ck
# 1         https://www.youtube.com/c/ChaibisketTelugu  Chai Bisket
# ...

# %% [markdown]
# 2) How many values are missing for each column and try dropping or replacing NULL values using appropriate pandas’ function.

# %%
# how many values are missing 
# before 
print("Before dropping rows with missing values")
print(df.isna().sum())

# droping rows with null values 
# method -1 : df[df.isnull().any(axis=1)]
df.dropna(inplace=True)

#after 
print("After dropping rows with missing values")
print(df.isna().sum())
# Out:
# Video Link                               0
# Video Views                              0
# Video Title                              0
# Channel URL                              0
# Creator Name                             0
# Creator Gender                           0
# Total Channel Subcribers                 0
# Total Chanel Views                       0
# Duration of Video                        0
# Duration in Seconds                      0
# Date of Video Upload                     0
# No of Likes                              0
# Language of the Video                    0
# Subtitle                                 0
# Video Description                        0
# Hashtags                                 0
# No of Comments                           0
# Date of the Last Comment                 0
# Maximum Quality of the Video             0
# No of Videos the Channel                 0
# No of Playlist                           0
# Premiered or Not                         0
# ...

# %% [markdown]
# 3) Drop the columns which are irrelevant features to feed into our model.

# %%
# suppose duration of video is irrelevent feature 
df.drop(['Duration of Video'],axis=1,inplace=True)

# %%
# # print in tabular form to see the change easily 
# from tabulate import tabulate
# print(tabulate(df, headers="keys", tablefmt="psql"))
df.head()
# Out:
#                                      Video Link Video Views  \
# 0   https://www.youtube.com/watch?v=_0fUOJ55gis     146,059
# 1   https://www.youtube.com/watch?v=_70MSLPRfZI     231,969
# 5   https://www.youtube.com/watch?v=_HwPGXsklyY     257,334
# 10  https://www.youtube.com/watch?v=0BBROgyHlFE   5,599,742
# 11  https://www.youtube.com/watch?v=0HheRYQ9ass      25,052
#
#                                           Video Title  \
# 0     Samse - Didupe Off-road Royal Enfield Himalayan
# 1                            Bhoom Baddhal Web Series
# 5                      HERO - Baananchige Oduva Baara
# 10  ROUNDER GLUTES: 5 Mistakes Keeping Your Butt Flat
# 11             The BEST Mockups You Will Find Online!
#
#                                     Channel URL         Creator Name  \
# 0           https://www.youtube.com/c/sriharick           srihari ck
# 1    https://www.youtube.com/c/ChaibisketTelugu          Chai Bisket
# ...

# %% [markdown]
# 4) Some columns are not statistical data but in the form of strings.
# It Is difficult for our model to learn when the data is in form of strings.
# Your task is to encode these strings using proper encoding techniques.

# %%
df.dtypes
# good resources : https://pbpython.com/categorical-encoding.html
# https://www.geeksforgeeks.org/ml-one-hot-encoding-of-datasets-in-python/

# for this question I will be encoding the "Creator gender" and "Language of the video" columns using proper encoding techniques.

# method -1 
temp = pd.get_dummies(df["Creator Gender"])

# %%
print(temp)
# Out:
#      Company  Female  Male
# 0          0       0     1
# 1          0       0     1
# 5          0       0     1
# 10         0       0     1
# 11         0       0     1
# ..       ...     ...   ...
# 892        0       0     1
# 893        0       0     1
# 894        0       1     0
# 895        0       1     0
# 896        0       1     0
#
# [563 rows x 3 columns]

# %%
df["Male"] = temp["Male"].to_list() 
df["Female"] = temp["Female"].to_list()
df.head()
# Out:
#                                      Video Link Video Views  \
# 0   https://www.youtube.com/watch?v=_0fUOJ55gis     146,059
# 1   https://www.youtube.com/watch?v=_70MSLPRfZI     231,969
# 5   https://www.youtube.com/watch?v=_HwPGXsklyY     257,334
# 10  https://www.youtube.com/watch?v=0BBROgyHlFE   5,599,742
# 11  https://www.youtube.com/watch?v=0HheRYQ9ass      25,052
#
#                                           Video Title  \
# 0     Samse - Didupe Off-road Royal Enfield Himalayan
# 1                            Bhoom Baddhal Web Series
# 5                      HERO - Baananchige Oduva Baara
# 10  ROUNDER GLUTES: 5 Mistakes Keeping Your Butt Flat
# 11             The BEST Mockups You Will Find Online!
#
#                                     Channel URL         Creator Name  \
# 0           https://www.youtube.com/c/sriharick           srihari ck
# 1    https://www.youtube.com/c/ChaibisketTelugu          Chai Bisket
# ...

# %%
# method 2  
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
label = label_encoder.fit_transform(df["Language of the Video"])
df["Language of the Video"] = label
df.head()
# Out:
#                                      Video Link Video Views  \
# 0   https://www.youtube.com/watch?v=_0fUOJ55gis     146,059
# 1   https://www.youtube.com/watch?v=_70MSLPRfZI     231,969
# 5   https://www.youtube.com/watch?v=_HwPGXsklyY     257,334
# 10  https://www.youtube.com/watch?v=0BBROgyHlFE   5,599,742
# 11  https://www.youtube.com/watch?v=0HheRYQ9ass      25,052
#
#                                           Video Title  \
# 0     Samse - Didupe Off-road Royal Enfield Himalayan
# 1                            Bhoom Baddhal Web Series
# 5                      HERO - Baananchige Oduva Baara
# 10  ROUNDER GLUTES: 5 Mistakes Keeping Your Butt Flat
# 11             The BEST Mockups You Will Find Online!
#
#                                     Channel URL         Creator Name  \
# 0           https://www.youtube.com/c/sriharick           srihari ck
# 1    https://www.youtube.com/c/ChaibisketTelugu          Chai Bisket
# ...
